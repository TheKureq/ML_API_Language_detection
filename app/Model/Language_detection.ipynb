# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

import warnings
warnings.simplefilter("ignore")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26408\739573577.py in <module>
# ----> 1 sklearn.__version__
#
# NameError: name 'sklearn' is not defined

# %%
# Loading the dataset
data = pd.read_csv("Language Detection.csv")

# %%
data.head(5)
# Out:
#                                                 Text Language
# 0   Nature, in the broadest sense, is the natural...  English
# 1  "Nature" can refer to the phenomena of the phy...  English
# 2  The study of nature is a large, if not the onl...  English
# 3  Although humans are part of nature, human acti...  English
# 4  [1] The word nature is borrowed from the Old F...  English

# %%
X = data["Text"]
y = data["Language"]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'

# %%
le.classes_
# Out:
# array(['Arabic', 'Danish', 'Dutch', 'English', 'French', 'German',
#        'Greek', 'Hindi', 'Italian', 'Kannada', 'Malayalam', 'Portugeese',
#        'Russian', 'Spanish', 'Sweedish', 'Tamil', 'Turkish'], dtype=object)

# %%
data_list = []
for text in X:
    text = re.sub(r'[!@#$(),\n"%^*?\:;~`0-9]', ' ', text)
    text = re.sub(r'[[]]', ' ', text)
    text = text.lower()
    data_list.append(text)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
# creating bag of words using countvectorizer

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
cv.fit(X_train)

x_train = cv.transform(X_train).toarray()
x_test  = cv.transform(X_test).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 0,  2,  9, ...,  3,  9, 13])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

ac = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
cr = classification_report(y_test, y_pred)

# %%
print("Accuracy is :",ac)
print(cr)
# Out:
# Accuracy is : 0.9792069632495164
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99        99
#            1       0.99      0.96      0.97        90
#            2       0.99      0.99      0.99       113
#            3       0.90      1.00      0.95       271
#            4       0.98      0.99      0.99       209
#            5       1.00      0.99      0.99        87
#            6       1.00      0.99      0.99        70
#            7       1.00      1.00      1.00         8
#            8       0.99      0.99      0.99       145
#            9       1.00      0.97      0.98        87
#           10       0.99      0.98      0.99       114
#           11       0.99      0.97      0.98       144
#           12       1.00      0.97      0.99       146
#           13       0.99      0.97      0.98       178
#           14       0.98      0.98      0.98       127
#           15       1.00      0.98      0.99        99
#           16       1.00      0.93      0.96        81
#
#     accuracy                           0.98      2068
#    macro avg       0.99      0.98      0.98      2068
# weighted avg       0.98      0.98      0.98      2068

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([('vectorizer', cv), ('multinomialNB', model)])
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()),
#                 ('multinomialNB', MultinomialNB())])

# %%
y_pred2 = pipe.predict(X_test)
ac2 = accuracy_score(y_test, y_pred2)
print("Accuracy is :",ac2)
# Out:
# Accuracy is : 0.9792069632495164

# %%
with open('trained_pipeline-0.1.0.pkl','wb') as f:
    pickle.dump(pipe, f)

# %%
# !zip -r ./trained_pipeline-0.1.0.pkl.zip ./trained_pipeline-0.1.0.pkl
# Out:
#   adding: trained_pipeline-0.1.0.pkl (172 bytes security) (deflated 95%)

# %%
# text = "Hello, how are you?"
text = "Ciao, come stai?"
#text = "Hi, how are you?"
y = pipe.predict([text])
le.classes_[y[0]], y
# Out:
# ('Italian', array([8]))
